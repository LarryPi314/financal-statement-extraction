# %% [markdown]
# ## This notebook contains my scratch-work for the development of what is to follow.

# %% [markdown]
# To begin, I played around with Azure AI's Document Intelligence capabilities. Here's some code trying out Azure AI's generic document processing.

# %%
from azure.ai.formrecognizer import DocumentAnalysisClient
from azure.core.credentials import AzureKeyCredential

endpoint = "https://beachpoint-case.cognitiveservices.azure.com/"
key = "8bVXMQDHEioJ3neUYwBPrRsyF6n571OEMExO8QEcV7O0khHasuBNJQQJ99AKAC4f1cMXJ3w3AAALACOGDDTR"

client = DocumentAnalysisClient(endpoint=endpoint, credential=AzureKeyCredential(key))

with open("data/apple_financial_statement.pdf", "rb") as document:
    poller = client.begin_analyze_document("prebuilt-document", document)
    result = poller.result()

print(result)
for document in result.documents:
    print(f"Document type: {document.doc_type}")
    for name, field in document.fields.items():
        print(f"Field: {name}, Value: {field.value}, Confidence: {field.confidence}")
# Out:
# AnalyzeResult(api_version=2023-07-31, model_id=prebuilt-document, content=Apple Inc.
# CONDENSED CONSOLIDATED STATEMENTS OF OPERATIONS (Unaudited) (In millions, except number of shares, which are reflected in thousands, and per-share amounts)
# Three Months Ended
# Twelve Months Ended
# September 28, 2024
# September 30, 2023
# September 28, September 30,
# 2024
# 2023
# Net sales:
# Products
# $ 69,958
# $ 67,184
# $ 294,866
# $ 298,085
# Services
# 24,972
# 22,314
# 96,169
# 85,200
# Total net sales (1)
# 94,930
# 89,498
# 391,035
# 383,285
# Cost of sales:
# Products
# 44,566
# 42,586
# 185,233
# 189,282
# Services
# 6,485
# 6,485
# 25,119
# 24,855
# Total cost of sales
# 51,051
# 49,071
# 210,352
# 214,137
# Gross margin
# 43,879
# 40,427
# 180,683
# 169,148
# Operating expenses:
# Research and development
# 7,765
# 7,307
# 31,370
# 29,915
# Selling, general and administrative
# 6,523
# 6,151
# 26,097
# 24,932
# Total operating expenses
# 14,288
# 13,458
# 57,467
# 54,847
# Operating income
# 29,591
# 26,969
# 123,216
# 114,301
# Other income/(expense), net
# 19
# 29
# 269
# (565)
# Income before provision for income taxes
# 29,610
# 26,998
# 123,485
# 113,736
# Provision for income taxes
# 14,874
# 4,042
# 29,749
# 16,741
# Net income
# $ 14,736
# $ 22,956
# $ 93,736
# $ 96,995
# Earnings per share:
# Basic
# $ 0.97
# $ 1.47
# $ 6.11
# $ 6.16
# Diluted
# $ 0.97
# $ 1.46
# $ 6.08
# $ 6.13
# Shares used in computing earnings per share:
# Basic
# 15,171,990
# 15,599,434
# 15,343,783
# 15,744,231
# Diluted
# 15,242,853
# 15,672,400
# 15,408,095
# 15,812,547
# (1) Net sales by reportable segment:
# Americas
# $ 41,664 $ 40,115
# $ 167,045 $ 162,560
# Europe
# 24,924
# 22,463
# 101,328
# 94,294
# Greater China
# 15,033
# 15,084
# 66,952
# 72,559
# Japan
# 5,926
# 5,505
# 25,052
# 24,257
# Rest of Asia Pacific
# 7,383
# 6,331
# 30,658
# 29,615
# Total net sales
# $ 94,930
# $ 89,498
# $ 391,035
# $ 383,285
# (1) Net sales by category:
# iPhone
# $ 46,222 $ 43,805 $ 201,183
# $ 200,583
# Mac
# 7,744
# 7,614
# 29,984
# 29,357
# iPad
# 6,950
# 6,443
# 26,694
# 28,300
# Wearables, Home and Accessories
# 9,042
# 9,322
# 37,005
# 39,845
# Services
# 24,972
# 22,314
# 96,169
# 85,200
# Total net sales
# $ 94,930
# $ 89,498
# $ 391,035
# $ 383,285
# Apple Inc.
# CONDENSED CONSOLIDATED BALANCE SHEETS (Unaudited) (In millions, except number of shares, which are reflected in thousands, and par value)
# September 28, 2024
# September 30, 2023
# ASSETS:
# Current assets:
# Cash and cash equivalents
# $ 29,943
# $ 29,965
# Marketable securities
# 35,228
# 31,590
# Accounts receivable, net
# 33,410
# 29,508
# Vendor non-trade receivables
# 32,833
# 31,477
# Inventories
# 7,286
# 6,331
# Other current assets
# 14,287
# 14,695
# Total current assets
# 152,987
# 143,566
# Non-current assets:
# Marketable securities
# 91,479
# 100,544
# Property, plant and equipment, net
# 45,680
# 43,715
# Other non-current assets
# 74,834
# 64,758
# Total non-current assets
# 211,993
# 209,017
# Total assets
# $ 364,980
# $ 352,583
# LIABILITIES AND SHAREHOLDERS' EQUITY:
# Current liabilities:
# Accounts payable
# $ 68,960 $ 62,611
# Other current liabilities
# 78,304
# 58,829
# Deferred revenue
# 8,249
# 8,061
# Commercial paper
# 9,967
# 5,985
# Term debt
# 10,912
# 9,822
# Total current liabilities
# 176,392
# 145,308
# Non-current liabilities:
# Term debt
# 85,750
# 95,281
# Other non-current liabilities
# 45,888
# 49,848
# Total non-current liabilities
# 131,638
# 145,129
# Total liabilities
# 308,030
# 290,437
# Commitments and contingencies
# Shareholders' equity:
# Common stock and additional paid-in capital, $0.00001 par value: 50,400,000 shares authorized; 15,116,786 and 15,550,061 shares issued and outstanding, respectively
# 83,276
# 73,812
# Accumulated deficit
# (19,154)
# (214)
# Accumulated other comprehensive loss
# (7,172)
# (11,452)
# Total shareholders' equity
# 56,950
# 62,146
# Total liabilities and shareholders' equity
# $ 364,980
# $ 352,583, languages=[], pages=[DocumentPage(page_number=1, angle=None, width=8.5, height=11.0, unit=inch, lines=[DocumentLine(content=Apple Inc., polygon=[Point(x=3.9253, y=0.5968), Point(x=4.5508, y=0.592), Point(x=4.5556, y=0.74), Point(x=3.9253, y=0.7448)], spans=[DocumentSpan(offset=0, length=10)]), DocumentLine(content=CONDENSED CONSOLIDATED STATEMENTS OF OPERATIONS (Unaudited), polygon=[Point(x=2.0056, y=0.8976), Point(x=6.4705, y=0.8976), Point(x=6.4705, y=1.0551), Point(x=2.0056, y=1.0503)], spans=[DocumentSpan(offset=11, length=59)]), DocumentLine(content=(In millions, except number of shares, which are reflected in thousands, and per-share amounts), polygon=[Point(x=1.5854, y=1.079), Point(x=6.8955, y=1.079), Point(x=6.8955, y=1.2318), Point(x=1.5854, y=1.2365)], spans=[DocumentSpan(offset=71, length=95)]), DocumentLine(content=Three Months Ended, polygon=[Point(x=4.5126, y=1.3893), Point(x=5.6492, y=1.3893), Point(x=5.6492, y=1.5182), Point(x=4.5126, y=1.5182)], spans=[DocumentSpan(offset=167, length=18)]), DocumentLine(content=Twelve Months Ended, polygon=[Point(x=6.3177, y=1.3941), Point(x=7.5211, y=1.3893), Point(x=7.5211, y=1.5182), Point(x=6.3177, y=1.5182)], spans=[DocumentSpan(offset=186, length=19)]), DocumentLine(content=September 28,, polygon=[Point(x=4.2404, y=1.5755), Point(x=5.0379, y=1.5755), Point(x=5.0379, y=1.6997), Point(x=4.2404, y=1.6997)], spans=[DocumentSpan(offset=206, length=13)]), DocumentLine(content=2024, polygon=[Point(x=4.4792, y=1.714), Point(x=4.761, y=1.7044), Point(x=4.7657, y=1.8142), Point(x=4.484, y=1.8142)], spans=[DocumentSpan(offset=220, length=4)]), DocumentLine(content=September 30,, polygon=[Point(x=5.143, y=1.5755), Point(x=5.9261, y=1.5755), Point(x=5.9261, y=1.7044), Point(x=5.143, y=1.6997)], spans=[DocumentSpan(offset=225, length=13)]), DocumentLine(content=2023, polygon=[Point(x=5.3913, y=1.714), Point(x=5.6826, y=1.7092), Point(x=5.6826, y=1.819), Point(x=5.3961, y=1.8142)], spans=[DocumentSpan(offset=239, length=4)]), DocumentLine(content=September 28, September 30,, polygon=[Point(x=6.0694, y=1.5755), Point(x=7.7646, y=1.5803), Point(x=7.7646, y=1.7044), Point(x=6.0694, y=1.6997)], spans=[DocumentSpan(offset=244, length=27)]), DocumentLine(content=2024, polygon=[Point(x=6.3081, y=1.714), Point(x=6.5994, y=1.7044), Point(x=6.6042, y=1.8142), Point(x=6.3129, y=1.8142)], spans=[DocumentSpan(offset=272, length=4)]), DocumentLine(content=2023, polygon=[Point(x=7.2298, y=1.714), Point(x=7.5067, y=1.7092), Point(x=7.5115, y=1.8142), Point(x=7.2346, y=1.8142)], spans=[DocumentSpan(offset=277, length=4)]), DocumentLine(content=Net sales:, polygon=[Point(x=0.7115, y=1.9145), Point(x=1.275, y=1.9145), Point(x=1.275, y=2.0339), Point(x=0.7115, y=2.0339)], spans=[DocumentSpan(offset=282, length=10)]), DocumentLine(content=Products, polygon=[Point(x=0.8022, y=2.115), Point(x=1.3228, y=2.115), Point(x=1.3228, y=2.2296), Point(x=0.8022, y=2.2296)], spans=[DocumentSpan(offset=293, length=8)]), DocumentLine(content=$, polygon=[Point(x=4.2261, y=2.1102), Point(x=4.3025, y=2.1102), Point(x=4.3073, y=2.2344), Point(x=4.2309, y=2.2296)], spans=[DocumentSpan(offset=302, length=1)]), DocumentLine(content=69,958, polygon=[Point(x=4.6225, y=2.0911), Point(x=5.0809, y=2.0911), Point(x=5.0809, y=2.2582), Point(x=4.6225, y=2.2487)], spans=[DocumentSpan(offset=304, length=6)]), DocumentLine(content=$, polygon=[Point(x=5.1287, y=2.1102), Point(x=5.2242, y=2.1102), Point(x=5.2242, y=2.2344), Point(x=5.1334, y=2.2296)], spans=[DocumentSpan(offset=311, length=1)]), DocumentLine(content=67,184, polygon=[Point(x=5.5346, y=2.1055), Point(x=5.9357, y=2.1055), Point(x=5.9309, y=2.2439), Point(x=5.5346, y=2.2439)], spans=[DocumentSpan(offset=313, length=6)]), DocumentLine(content=$, polygon=[Point(x=6.0503, y=2.1102), Point(x=6.1362, y=2.1055), Point(x=6.1362, y=2.2296), Point(x=6.0551, y=2.2248)], spans=[DocumentSpan(offset=320, length=1)]), DocumentLine(content=294,866, polygon=[Point(x=6.3559, y=2.086 ...
# 2024, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=6.0052, y=1.5401), Point(x=6.9198, y=1.5401), Point(x=6.9198, y=1.8668), Point(x=6.0052, y=1.8668)])], spans=[DocumentSpan(offset=244, length=13), DocumentSpan(offset=272, length=4)]), DocumentParagraph(role=None, content=September 30,
# 2023, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=6.9198, y=1.5401), Point(x=7.7972, y=1.5401), Point(x=7.7972, y=1.8668), Point(x=6.9198, y=1.8668)])], spans=[DocumentSpan(offset=258, length=13), DocumentSpan(offset=277, length=4)]), DocumentParagraph(role=None, content=Net sales:, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=0.6666, y=1.8668), Point(x=3.7185, y=1.8668), Point(x=3.7185, y=2.0348), Point(x=0.6666, y=2.0441)])], spans=[DocumentSpan(offset=282, length=10)]), DocumentParagraph(role=None, content=Products, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=0.6666, y=2.0441), Point(x=3.7185, y=2.0348), Point(x=3.7185, y=2.2401), Point(x=0.6666, y=2.2495)])], spans=[DocumentSpan(offset=293, length=8)]), DocumentParagraph(role=None, content=$ 69,958, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=3.7185, y=2.0348), Point(x=5.0905, y=2.0348), Point(x=5.0905, y=2.2401), Point(x=3.7185, y=2.2401)])], spans=[DocumentSpan(offset=302, length=8)]), DocumentParagraph(role=None, content=$ 67,184, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=5.0905, y=2.0348), Point(x=6.0052, y=2.0348), Point(x=6.0052, y=2.2401), Point(x=5.0905, y=2.2401)])], spans=[DocumentSpan(offset=311, length=8)]), DocumentParagraph(role=None, content=$ 294,866, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=6.0052, y=2.0348), Point(x=6.9198, y=2.0348), Point(x=6.9198, y=2.2401), Point(x=6.0052, y=2.2401)])], spans=[DocumentSpan(offset=320, length=9)]), DocumentParagraph(role=None, content=$ 298,085, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=6.9198, y=2.0348), Point(x=7.7972, y=2.0348), Point(x=7.7972, y=2.2401), Point(x=6.9198, y=2.2401)])], spans=[DocumentSpan(offset=330, length=9)]), DocumentParagraph(role=None, content=Services, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=0.6666, y=2.2495), Point(x=3.7185, y=2.2401), Point(x=3.7185, y=2.4455), Point(x=0.6666, y=2.4548)])], spans=[DocumentSpan(offset=340, length=8)]), DocumentParagraph(role=None, content=24,972, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=3.7185, y=2.2401), Point(x=5.0905, y=2.2401), Point(x=5.0905, y=2.4455), Point(x=3.7185, y=2.4455)])], spans=[DocumentSpan(offset=349, length=6)]), DocumentParagraph(role=None, content=22,314, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=5.0905, y=2.2401), Point(x=6.0052, y=2.2401), Point(x=6.0052, y=2.4455), Point(x=5.0905, y=2.4455)])], spans=[DocumentSpan(offset=356, length=6)]), DocumentParagraph(role=None, content=96,169, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=6.0052, y=2.2401), Point(x=6.9198, y=2.2401), Point(x=6.9198, y=2.4455), Point(x=6.0052, y=2.4455)])], spans=[DocumentSpan(offset=363, length=6)]), DocumentParagraph(role=None, content=85,200, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=6.9198, y=2.2401), Point(x=7.7972, y=2.2401), Point(x=7.7972, y=2.4455), Point(x=6.9198, y=2.4455)])], spans=[DocumentSpan(offset=370, length=6)]), DocumentParagraph(role=None, content=Total net sales (1), bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=0.6666, y=2.4548), Point(x=3.7185, y=2.4455), Point(x=3.7185, y=2.6415), Point(x=0.6666, y=2.6415)])], spans=[DocumentSpan(offset=377, length=19)]), DocumentParagraph(role=None, content=94,930, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=3.7185, y=2.4455), Point(x=5.0905, y=2.4455), Point(x=5.0905, y=2.6415), Point(x=3.7185, y=2.6415)])], spans=[DocumentSpan(offset=397, length=6)]), DocumentParagraph(role=None, content=89,498, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=5.0905, y=2.4455), Point(x=6.0052, y=2.4455), Point(x=6.0052, y=2.6415), Point(x=5.0905, y=2.6415)])], spans=[DocumentSpan(offset=404, length=6)]), DocumentParagraph(role=None, content=391,035, bounding_regions=[BoundingRegion(page_number=1, polyg ...
# 2024, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=6.0052, y=1.5401), Point(x=6.9198, y=1.5401), Point(x=6.9198, y=1.8668), Point(x=6.0052, y=1.8668)])], spans=[DocumentSpan(offset=244, length=13), DocumentSpan(offset=272, length=4)]), DocumentTableCell(kind=columnHeader, row_index=1, column_index=4, row_span=1, column_span=1, content=September 30,
# 2023, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=6.9198, y=1.5401), Point(x=7.7972, y=1.5401), Point(x=7.7972, y=1.8668), Point(x=6.9198, y=1.8668)])], spans=[DocumentSpan(offset=258, length=13), DocumentSpan(offset=277, length=4)]), DocumentTableCell(kind=content, row_index=2, column_index=0, row_span=1, column_span=1, content=Net sales:, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=0.6666, y=1.8668), Point(x=3.7185, y=1.8668), Point(x=3.7185, y=2.0348), Point(x=0.6666, y=2.0441)])], spans=[DocumentSpan(offset=282, length=10)]), DocumentTableCell(kind=content, row_index=2, column_index=1, row_span=1, column_span=1, content=, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=3.7185, y=1.8668), Point(x=5.0905, y=1.8668), Point(x=5.0905, y=2.0348), Point(x=3.7185, y=2.0348)])], spans=[]), DocumentTableCell(kind=content, row_index=2, column_index=2, row_span=1, column_span=1, content=, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=5.0905, y=1.8668), Point(x=6.0052, y=1.8668), Point(x=6.0052, y=2.0348), Point(x=5.0905, y=2.0348)])], spans=[]), DocumentTableCell(kind=content, row_index=2, column_index=3, row_span=1, column_span=1, content=, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=6.0052, y=1.8668), Point(x=6.9198, y=1.8668), Point(x=6.9198, y=2.0348), Point(x=6.0052, y=2.0348)])], spans=[]), DocumentTableCell(kind=content, row_index=2, column_index=4, row_span=1, column_span=1, content=, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=6.9198, y=1.8668), Point(x=7.7972, y=1.8668), Point(x=7.7972, y=2.0348), Point(x=6.9198, y=2.0348)])], spans=[]), DocumentTableCell(kind=content, row_index=3, column_index=0, row_span=1, column_span=1, content=Products, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=0.6666, y=2.0441), Point(x=3.7185, y=2.0348), Point(x=3.7185, y=2.2401), Point(x=0.6666, y=2.2495)])], spans=[DocumentSpan(offset=293, length=8)]), DocumentTableCell(kind=content, row_index=3, column_index=1, row_span=1, column_span=1, content=$ 69,958, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=3.7185, y=2.0348), Point(x=5.0905, y=2.0348), Point(x=5.0905, y=2.2401), Point(x=3.7185, y=2.2401)])], spans=[DocumentSpan(offset=302, length=8)]), DocumentTableCell(kind=content, row_index=3, column_index=2, row_span=1, column_span=1, content=$ 67,184, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=5.0905, y=2.0348), Point(x=6.0052, y=2.0348), Point(x=6.0052, y=2.2401), Point(x=5.0905, y=2.2401)])], spans=[DocumentSpan(offset=311, length=8)]), DocumentTableCell(kind=content, row_index=3, column_index=3, row_span=1, column_span=1, content=$ 294,866, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=6.0052, y=2.0348), Point(x=6.9198, y=2.0348), Point(x=6.9198, y=2.2401), Point(x=6.0052, y=2.2401)])], spans=[DocumentSpan(offset=320, length=9)]), DocumentTableCell(kind=content, row_index=3, column_index=4, row_span=1, column_span=1, content=$ 298,085, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=6.9198, y=2.0348), Point(x=7.7972, y=2.0348), Point(x=7.7972, y=2.2401), Point(x=6.9198, y=2.2401)])], spans=[DocumentSpan(offset=330, length=9)]), DocumentTableCell(kind=content, row_index=4, column_index=0, row_span=1, column_span=1, content=Services, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=0.6666, y=2.2495), Point(x=3.7185, y=2.2401), Point(x=3.7185, y=2.4455), Point(x=0.6666, y=2.4548)])], spans=[DocumentSpan(offset=340, length=8)]), DocumentTableCell(kind=content, row_index=4, column_index=1, row_span=1, column_span=1, content=24,972, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=3.7185, y=2.2401), Point(x=5.0905, y=2.2401), Point(x=5.0905, y=2.4455), Point(x=3.7185, y=2.4455)])], spans=[DocumentSpan(offset=349, length=6)]), DocumentTableCell(kind=content, row_index=4, column_index=2, row_span=1, column_s ...
# 73,812, bounding_regions=[BoundingRegion(page_number=2, polygon=[Point(x=6.3511, y=8.935), Point(x=7.7654, y=8.9437), Point(x=7.7645, y=9.0846), Point(x=6.3503, y=9.076)])], spans=[DocumentSpan(offset=3207, length=13)]), confidence=0.368)], styles=[DocumentStyle(is_handwritten=True, spans=[DocumentSpan(offset=1552, length=1)], confidence=0.1, similar_font_family=None, font_style=None, font_weight=None, color=None, background_color=None)], documents=[])

# %% [markdown]
# Later down the way, I realized the importance of prompting the LLM to obtain structured data (this effectively reduces hallucination and forces the model to extract only the desired information). Here's code experimenting with OpenAI's APIs for structured LLM output.

# %%
import openai
from openai import OpenAI
import os
from azure.ai.formrecognizer import DocumentAnalysisClient
from azure.core.credentials import AzureKeyCredential
import openpyxl
from prompt import FinancialStatementExtract
import json

from dotenv import load_dotenv

load_dotenv()

AZURE_DOCUMENT_ANALYZER_KEY = os.getenv("AZURE_DOCUMENT_ANALYZER_KEY")
AZURE_DOCUMENT_ANALYZER_ENDPOINT = os.getenv("AZURE_DOCUMENT_ANALYZER_ENDPOINT")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

document_client = DocumentAnalysisClient(
    endpoint=AZURE_DOCUMENT_ANALYZER_ENDPOINT,
    credential=AzureKeyCredential(AZURE_DOCUMENT_ANALYZER_KEY)
)
openai_client = OpenAI(api_key=OPENAI_API_KEY)

'''
This function takes in a PDF file path, extracts tables from the PDF
using Azure Document Analysis and returns the tables as a list of rows.
'''
def extract_tables_from_pdf(pdf_path):
    try:
        with open(pdf_path, "rb") as pdf_file:
            poller = document_client.begin_analyze_document("prebuilt-layout", document=pdf_file)
            result = poller.result()

        tables = []
        for table in result.tables:
            rows = []
            for row_idx in range(table.row_count):
                row = []
                for cell in table.cells:
                    if cell.row_index == row_idx:
                        row.append(cell.content)
                rows.append(row)
            tables.append(rows)
        return tables
    except Exception as e:
        print(f"Error extracting tables: {e}")
        return []

'''
This function takes in the parsed tables and prompts OpenAI
to extract the desired information and format it. 
'''
def parse_tables_with_openai(tables):
    with open('data/prompt.txt', 'r') as f:
        prompt = f.read()
    
    for table in tables:
        prompt += "\n".join(["\t".join(row) for row in table]) + "\n\n"

    try:
        response = openai_client.beta.chat.completions.parse(
            model="gpt-4o-2024-08-06", 
            messages=[
                {"role": "system", "content": "You are a helpful assistant for structured financial data extraction. You will be given unstructured text from a research paper and should convert it into the given structure."},
                {"role": "user", "content": prompt}
            ],
            response_format=FinancialStatementExtract
        )
        return response.choices[0].message.parsed
    except Exception as e:
        print(f"Error parsing tables with OpenAI: {e}")
        return ""


pdf_path = "data/apple_financial_statement.pdf"  
output_path = "data/apple_financial_metrics.xlsx"

print("Extracting tables from PDF...")
tables = extract_tables_from_pdf(pdf_path)
print(f"Hello world! {tables}")
print("Parsing tables with OpenAI...")

parsed_data = parse_tables_with_openai(tables)

glob_items = parsed_data
print(type(glob_items))

for key, value in glob_items:
    print(f"type of key: {type(key)}, type of value: {type(value)}")
    print(f"KEY: {key}, VALUE: {value}")

    vals = value.split('|')
    vals.append('N/A')
    
    print(vals)
    if value == 'N/A':
        print([str(key), 'N/A', 'N/A'])
    else:
        print([str(key), vals[0], vals[1]])
    print()
# Out:
# Extracting tables from PDF...
# Hello world! [[['', 'Three Months Ended', 'Twelve Months Ended'], ['September 28, 2024', 'September 30, 2023', 'September 28,\n2024', 'September 30,\n2023'], ['Net sales:', '', '', '', ''], ['Products', '$ 69,958', '$ 67,184', '$ 294,866', '$ 298,085'], ['Services', '24,972', '22,314', '96,169', '85,200'], ['Total net sales (1)', '94,930', '89,498', '391,035', '383,285'], ['Cost of sales:', '', '', '', ''], ['Products', '44,566', '42,586', '185,233', '189,282'], ['Services', '6,485', '6,485', '25,119', '24,855'], ['Total cost of sales', '51,051', '49,071', '210,352', '214,137'], ['Gross margin', '43,879', '40,427', '180,683', '169,148'], ['', '', '', '', ''], ['Operating expenses:', '', '', '', ''], ['Research and development', '7,765', '7,307', '31,370', '29,915'], ['Selling, general and administrative', '6,523', '6,151', '26,097', '24,932'], ['Total operating expenses', '14,288', '13,458', '57,467', '54,847'], ['', '', '', '', ''], ['Operating income', '29,591', '26,969', '123,216', '114,301'], ['Other income/(expense), net', '19', '29', '269', '(565)'], ['Income before provision for income taxes', '29,610', '26,998', '123,485', '113,736'], ['Provision for income taxes', '14,874', '4,042', '29,749', '16,741'], ['Net income', '$ 14,736', '$ 22,956', '$ 93,736', '$ 96,995'], ['', '', '', '', ''], ['Earnings per share:', '', '', '', ''], ['Basic', '$ 0.97', '$ 1.47', '$ 6.11', '$ 6.16'], ['Diluted', '$ 0.97', '$ 1.46', '$ 6.08', '$ 6.13'], ['Shares used in computing earnings per share:', '', '', '', ''], ['Basic', '15,171,990', '15,599,434', '15,343,783', '15,744,231'], ['Diluted', '15,242,853', '15,672,400', '15,408,095', '15,812,547'], ['', '', '', '', ''], ['(1) Net sales by reportable segment:', '', '', '', ''], ['Americas', '$ 41,664', '$ 40,115', '$ 167,045', '$ 162,560'], ['Europe', '24,924', '22,463', '101,328', '94,294'], ['Greater China', '15,033', '15,084', '66,952', '72,559'], ['Japan', '5,926', '5,505', '25,052', '24,257'], ['Rest of Asia Pacific', '7,383', '6,331', '30,658', '29,615'], ['Total net sales', '$ 94,930', '$ 89,498', '$ 391,035', '$ 383,285'], ['', '', '', '', ''], ['(1) Net sales by category:', '', '', '', ''], ['iPhone', '$ 46,222', '$ 43,805', '$ 201,183', '$ 200,583'], ['Mac', '7,744', '7,614', '29,984', '29,357'], ['iPad', '6,950', '6,443', '26,694', '28,300'], ['Wearables, Home and Accessories', '9,042', '9,322', '37,005', '39,845'], ['Services', '24,972', '22,314', '96,169', '85,200'], ['Total net sales', '$ 94,930', '$ 89,498', '$ 391,035', '$ 383,285']], [['', 'September 28, 2024', 'September 30, 2023'], ['ASSETS:', '', ''], ['Current assets:', '', ''], ['Cash and cash equivalents', '$ 29,943', '$ 29,965'], ['Marketable securities', '35,228', '31,590'], ['Accounts receivable, net', '33,410', '29,508'], ['Vendor non-trade receivables', '32,833', '31,477'], ['Inventories', '7,286', '6,331'], ['Other current assets', '14,287', '14,695'], ['Total current assets', '152,987', '143,566'], ['', '', ''], ['Non-current assets:', '', ''], ['Marketable securities', '91,479', '100,544'], ['Property, plant and equipment, net', '45,680', '43,715'], ['Other non-current assets', '74,834', '64,758'], ['Total non-current assets', '211,993', '209,017'], ['Total assets', '$ 364,980', '$ 352,583'], ['', '', ''], ["LIABILITIES AND SHAREHOLDERS' EQUITY:", '', ''], ['Current liabilities:', '', ''], ['Accounts payable', '$ 68,960', '$ 62,611'], ['Other current liabilities', '78,304', '58,829'], ['Deferred revenue', '8,249', '8,061'], ['Commercial paper', '9,967', '5,985'], ['Term debt', '10,912', '9,822'], ['Total current liabilities', '176,392', '145,308'], ['', '', ''], ['Non-current liabilities:', '', ''], ['Term debt', '85,750', '95,281'], ['Other non-current liabilities', '45,888', '49,848'], ['Total non-current liabilities', '131,638', '145,129'], ['Total liabilities', '308,030', '290,437'], ['', '', ''], ['Commitments and contingencies', '', ''], ['', '', ''], ["Shareholders' equity:", '', ''], ['Common stock an ...
# Parsing tables with OpenAI...
# SHREK
# <class 'prompt.FinancialStatementExtract'>
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Income_statement_millions, VALUE: $391,035M| $383,285M
# ['Income_statement_millions', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Revenue_Item_1, VALUE: N/A
# ['Revenue_Item_1', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Revenue_Item_2, VALUE: N/A
# ['Revenue_Item_2', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Revenue_Item_3, VALUE: N/A
# ['Revenue_Item_3', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Sales, VALUE: $391,035M| $383,285M
# ['Sales', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Cost_of_Sales, VALUE: $210,352M| $214,137M
# ['Cost_of_Sales', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Selling_General_and_Administrative, VALUE: $26,097M| $24,932M
# ['Selling_General_and_Administrative', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Cost_Item_1, VALUE: N/A
# ['Cost_Item_1', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Cost_Item_2, VALUE: N/A
# ['Cost_Item_2', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Cost_Item_3, VALUE: N/A
# ['Cost_Item_3', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Operating_Income, VALUE: $123,216M| $114,301M
# ['Operating_Income', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Interest_Expense, VALUE: N/A
# ['Interest_Expense', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Other_Income_expense_net, VALUE: $269M| ($565M)
# ['Other_Income_expense_net', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Provision_for_Income_Tax, VALUE: $29,749M| $16,741M
# ['Provision_for_Income_Tax', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Earnings_from_Discontinued_Operations, VALUE: N/A
# ['Earnings_from_Discontinued_Operations', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Net_Income, VALUE: $93,736M| $96,995M
# ['Net_Income', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Adjusted_Operating_Income, VALUE: N/A
# ['Adjusted_Operating_Income', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Income_Taxes, VALUE: N/A
# ['Income_Taxes', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Depreciation_Amortization, VALUE: N/A
# ['Depreciation_Amortization', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Adjusted_EBITDA, VALUE: N/A
# ['Adjusted_EBITDA', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Adjustment_1, VALUE: N/A
# ['Adjustment_1', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Adjustment_2, VALUE: N/A
# ['Adjustment_2', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Adjustment_3, VALUE: N/A
# ['Adjustment_3', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Adjustment_4, VALUE: N/A
# ['Adjustment_4', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Cash_Adjustments, VALUE: N/A
# ['Cash_Adjustments', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Cash_Flow_Statement, VALUE: N/A
# ['Cash_Flow_Statement', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Operating_Activities, VALUE: N/A
# ['Operating_Activities', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Depreciation_and_Amortization, VALUE: N/A
# ['Depreciation_and_Amortization', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Operating_Activity_1, VALUE: N/A
# ['Operating_Activity_1', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Operating_Activity_2, VALUE: N/A
# ['Operating_Activity_2', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Operating_Activity_3, VALUE: N/A
# ['Operating_Activity_3', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Operating_Activity_4, VALUE: N/A
# ['Operating_Activity_4', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Operating_Activity_5, VALUE: N/A
# ['Operating_Activity_5', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Operating_Activity_6, VALUE: N/A
# ['Operating_Activity_6', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Change_in_Working_Capital, VALUE: N/A
# ['Change_in_Working_Capital', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Cash_Flow_From_Operating_Activities, VALUE: N/A
# ['Cash_Flow_From_Operating_Activities', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Working_Capital, VALUE: N/A
# ['Working_Capital', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Accounts_Receivable, VALUE: N/A
# ['Accounts_Receivable', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Inventories, VALUE: N/A
# ['Inventories', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Prepaid_Expenses_and_Other_Current_Assets, VALUE: N/A
# ['Prepaid_Expenses_and_Other_Current_Assets', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Accounts_Payable, VALUE: N/A
# ['Accounts_Payable', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Accrued_Expenses, VALUE: N/A
# ['Accrued_Expenses', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Due_From_Due_to_Related_Party, VALUE: N/A
# ['Due_From_Due_to_Related_Party', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Income_Taxes_Payables, VALUE: N/A
# ['Income_Taxes_Payables', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Others, VALUE: N/A
# ['Others', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Capital_Expenditures, VALUE: N/A
# ['Capital_Expenditures', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Activity_1, VALUE: N/A
# ['Activity_1', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Activity_2, VALUE: N/A
# ['Activity_2', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Activity_3, VALUE: N/A
# ['Activity_3', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Cash_Flow_From_Investing_Activities, VALUE: N/A
# ['Cash_Flow_From_Investing_Activities', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Borrowings_net, VALUE: N/A
# ['Borrowings_net', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Shortterm_Borrowings_from_Parent_Net, VALUE: N/A
# ['Shortterm_Borrowings_from_Parent_Net', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Related_Party_Loans_Net, VALUE: N/A
# ['Related_Party_Loans_Net', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Debt_Issuance_Costs, VALUE: N/A
# ['Debt_Issuance_Costs', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Net_Transfer_to_Parent, VALUE: N/A
# ['Net_Transfer_to_Parent', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Dividends, VALUE: N/A
# ['Dividends', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Other, VALUE: N/A
# ['Other', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Cash_Flow_From_Financing_Activities, VALUE: N/A
# ['Cash_Flow_From_Financing_Activities', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Foreign_Exchange_Rate_Effect_on_Cash_and_Cash_Equivalents, VALUE: N/A
# ['Foreign_Exchange_Rate_Effect_on_Cash_and_Cash_Equivalents', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Discontinued_Operations_Cash_Flows, VALUE: N/A
# ['Discontinued_Operations_Cash_Flows', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Discontinued_Operations_Cash_Balance, VALUE: N/A
# ['Discontinued_Operations_Cash_Balance', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Change_In_Cash_Cash_Equiv, VALUE: N/A
# ['Change_In_Cash_Cash_Equiv', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Cash_And_Cash_Equivalents_Beginning_Of_Period, VALUE: N/A
# ['Cash_And_Cash_Equivalents_Beginning_Of_Period', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Cash_And_Cash_Equivalents_End_Of_Period, VALUE: N/A
# ['Cash_And_Cash_Equivalents_End_Of_Period', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Current_Assets, VALUE: $152,987M| $143,566M
# ['Current_Assets', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Cash_and_Cash_Equivalents, VALUE: $29,943M| $29,965M
# ['Cash_and_Cash_Equivalents', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Accounts_Receivables, VALUE: $33,410M| $29,508M
# ['Accounts_Receivables', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Other_Current_Assets, VALUE: $14,287M| $14,695M
# ['Other_Current_Assets', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Current_Assets_of_Discontinued_Operations, VALUE: N/A
# ['Current_Assets_of_Discontinued_Operations', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Total_Current_Assets, VALUE: $152,987M| $143,566M
# ['Total_Current_Assets', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Property_Plant_and_Equipment_Net, VALUE: $45,680M| $43,715M
# ['Property_Plant_and_Equipment_Net', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Goodwill, VALUE: N/A
# ['Goodwill', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Other_Intangiblesnet, VALUE: N/A
# ['Other_Intangiblesnet', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Other_Assets, VALUE: $74,834M| $64,758M
# ['Other_Assets', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Noncurrent_Assets_of_Discontinued_Operations, VALUE: N/A
# ['Noncurrent_Assets_of_Discontinued_Operations', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Total_Assets, VALUE: $364,980M| $352,583M
# ['Total_Assets', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Current_Liabilities, VALUE: $176,392M| $145,308M
# ['Current_Liabilities', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Trade_Accounts_Payable, VALUE: $68,960M| $62,611M
# ['Trade_Accounts_Payable', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Accrued_and_Other_Current_Liabilities, VALUE: N/A
# ['Accrued_and_Other_Current_Liabilities', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Due_to_Related_Party, VALUE: N/A
# ['Due_to_Related_Party', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Income_Taxes_Payable, VALUE: N/A
# ['Income_Taxes_Payable', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Current_Liabilities_of_Discontinued_Operations, VALUE: N/A
# ['Current_Liabilities_of_Discontinued_Operations', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Current_Portion_of_Debt, VALUE: N/A
# ['Current_Portion_of_Debt', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Total_Current_Liabilities, VALUE: $176,392M| $145,308M
# ['Total_Current_Liabilities', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Long_Term_Debt, VALUE: $85,750M| $95,281M
# ['Long_Term_Debt', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Deferred_Income_Taxes, VALUE: N/A
# ['Deferred_Income_Taxes', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Other_Noncurrent_Liabilities, VALUE: $45,888M| $49,848M
# ['Other_Noncurrent_Liabilities', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Noncurrent_Liabilities_of_Discontinued_Operation, VALUE: N/A
# ['Noncurrent_Liabilities_of_Discontinued_Operation', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Total_Liabilities, VALUE: $308,030M| $290,437M
# ['Total_Liabilities', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Shareholder_Equity, VALUE: $56,950M| $62,146M
# ['Shareholder_Equity', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Total_Liabilities_And_Shareholders_Equities, VALUE: $364,980M| $352,583M
# ['Total_Liabilities_And_Shareholders_Equities', 'N/A', 'N/A']

# %%
for key, value in glob_items:
    print(f"type of key: {type(key)}, type of value: {type(value)}")
    print(f"KEY: {key}, VALUE: {value}")

    vals = value.split('|')
    vals.append('N/A')
    
    print(vals)
    if value == 'N/A':
        print([str(key), 'N/A', 'N/A'])
    else:
        print([str(key), vals[0], vals[1]])
    print()
# Out:
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Income_statement_millions, VALUE: $391,035M| $383,285M
# ['$391,035M', ' $383,285M', 'N/A']
# ['Income_statement_millions', '$391,035M', ' $383,285M']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Revenue_Item_1, VALUE: N/A
# ['N/A', 'N/A']
# ['Revenue_Item_1', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Revenue_Item_2, VALUE: N/A
# ['N/A', 'N/A']
# ['Revenue_Item_2', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Revenue_Item_3, VALUE: N/A
# ['N/A', 'N/A']
# ['Revenue_Item_3', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Sales, VALUE: $391,035M| $383,285M
# ['$391,035M', ' $383,285M', 'N/A']
# ['Sales', '$391,035M', ' $383,285M']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Cost_of_Sales, VALUE: $210,352M| $214,137M
# ['$210,352M', ' $214,137M', 'N/A']
# ['Cost_of_Sales', '$210,352M', ' $214,137M']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Selling_General_and_Administrative, VALUE: $26,097M| $24,932M
# ['$26,097M', ' $24,932M', 'N/A']
# ['Selling_General_and_Administrative', '$26,097M', ' $24,932M']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Cost_Item_1, VALUE: N/A
# ['N/A', 'N/A']
# ['Cost_Item_1', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Cost_Item_2, VALUE: N/A
# ['N/A', 'N/A']
# ['Cost_Item_2', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Cost_Item_3, VALUE: N/A
# ['N/A', 'N/A']
# ['Cost_Item_3', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Operating_Income, VALUE: $123,216M| $114,301M
# ['$123,216M', ' $114,301M', 'N/A']
# ['Operating_Income', '$123,216M', ' $114,301M']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Interest_Expense, VALUE: N/A
# ['N/A', 'N/A']
# ['Interest_Expense', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Other_Income_expense_net, VALUE: $269M| ($565M)
# ['$269M', ' ($565M)', 'N/A']
# ['Other_Income_expense_net', '$269M', ' ($565M)']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Provision_for_Income_Tax, VALUE: $29,749M| $16,741M
# ['$29,749M', ' $16,741M', 'N/A']
# ['Provision_for_Income_Tax', '$29,749M', ' $16,741M']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Earnings_from_Discontinued_Operations, VALUE: N/A
# ['N/A', 'N/A']
# ['Earnings_from_Discontinued_Operations', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Net_Income, VALUE: $93,736M| $96,995M
# ['$93,736M', ' $96,995M', 'N/A']
# ['Net_Income', '$93,736M', ' $96,995M']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Adjusted_Operating_Income, VALUE: N/A
# ['N/A', 'N/A']
# ['Adjusted_Operating_Income', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Income_Taxes, VALUE: N/A
# ['N/A', 'N/A']
# ['Income_Taxes', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Depreciation_Amortization, VALUE: N/A
# ['N/A', 'N/A']
# ['Depreciation_Amortization', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Adjusted_EBITDA, VALUE: N/A
# ['N/A', 'N/A']
# ['Adjusted_EBITDA', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Adjustment_1, VALUE: N/A
# ['N/A', 'N/A']
# ['Adjustment_1', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Adjustment_2, VALUE: N/A
# ['N/A', 'N/A']
# ['Adjustment_2', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Adjustment_3, VALUE: N/A
# ['N/A', 'N/A']
# ['Adjustment_3', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Adjustment_4, VALUE: N/A
# ['N/A', 'N/A']
# ['Adjustment_4', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Cash_Adjustments, VALUE: N/A
# ['N/A', 'N/A']
# ['Cash_Adjustments', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Cash_Flow_Statement, VALUE: N/A
# ['N/A', 'N/A']
# ['Cash_Flow_Statement', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Operating_Activities, VALUE: N/A
# ['N/A', 'N/A']
# ['Operating_Activities', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Depreciation_and_Amortization, VALUE: N/A
# ['N/A', 'N/A']
# ['Depreciation_and_Amortization', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Operating_Activity_1, VALUE: N/A
# ['N/A', 'N/A']
# ['Operating_Activity_1', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Operating_Activity_2, VALUE: N/A
# ['N/A', 'N/A']
# ['Operating_Activity_2', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Operating_Activity_3, VALUE: N/A
# ['N/A', 'N/A']
# ['Operating_Activity_3', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Operating_Activity_4, VALUE: N/A
# ['N/A', 'N/A']
# ['Operating_Activity_4', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Operating_Activity_5, VALUE: N/A
# ['N/A', 'N/A']
# ['Operating_Activity_5', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Operating_Activity_6, VALUE: N/A
# ['N/A', 'N/A']
# ['Operating_Activity_6', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Change_in_Working_Capital, VALUE: N/A
# ['N/A', 'N/A']
# ['Change_in_Working_Capital', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Cash_Flow_From_Operating_Activities, VALUE: N/A
# ['N/A', 'N/A']
# ['Cash_Flow_From_Operating_Activities', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Working_Capital, VALUE: N/A
# ['N/A', 'N/A']
# ['Working_Capital', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Accounts_Receivable, VALUE: N/A
# ['N/A', 'N/A']
# ['Accounts_Receivable', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Inventories, VALUE: N/A
# ['N/A', 'N/A']
# ['Inventories', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Prepaid_Expenses_and_Other_Current_Assets, VALUE: N/A
# ['N/A', 'N/A']
# ['Prepaid_Expenses_and_Other_Current_Assets', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Accounts_Payable, VALUE: N/A
# ['N/A', 'N/A']
# ['Accounts_Payable', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Accrued_Expenses, VALUE: N/A
# ['N/A', 'N/A']
# ['Accrued_Expenses', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Due_From_Due_to_Related_Party, VALUE: N/A
# ['N/A', 'N/A']
# ['Due_From_Due_to_Related_Party', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Income_Taxes_Payables, VALUE: N/A
# ['N/A', 'N/A']
# ['Income_Taxes_Payables', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Others, VALUE: N/A
# ['N/A', 'N/A']
# ['Others', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Capital_Expenditures, VALUE: N/A
# ['N/A', 'N/A']
# ['Capital_Expenditures', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Activity_1, VALUE: N/A
# ['N/A', 'N/A']
# ['Activity_1', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Activity_2, VALUE: N/A
# ['N/A', 'N/A']
# ['Activity_2', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Activity_3, VALUE: N/A
# ['N/A', 'N/A']
# ['Activity_3', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Cash_Flow_From_Investing_Activities, VALUE: N/A
# ['N/A', 'N/A']
# ['Cash_Flow_From_Investing_Activities', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Borrowings_net, VALUE: N/A
# ['N/A', 'N/A']
# ['Borrowings_net', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Shortterm_Borrowings_from_Parent_Net, VALUE: N/A
# ['N/A', 'N/A']
# ['Shortterm_Borrowings_from_Parent_Net', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Related_Party_Loans_Net, VALUE: N/A
# ['N/A', 'N/A']
# ['Related_Party_Loans_Net', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Debt_Issuance_Costs, VALUE: N/A
# ['N/A', 'N/A']
# ['Debt_Issuance_Costs', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Net_Transfer_to_Parent, VALUE: N/A
# ['N/A', 'N/A']
# ['Net_Transfer_to_Parent', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Dividends, VALUE: N/A
# ['N/A', 'N/A']
# ['Dividends', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Other, VALUE: N/A
# ['N/A', 'N/A']
# ['Other', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Cash_Flow_From_Financing_Activities, VALUE: N/A
# ['N/A', 'N/A']
# ['Cash_Flow_From_Financing_Activities', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Foreign_Exchange_Rate_Effect_on_Cash_and_Cash_Equivalents, VALUE: N/A
# ['N/A', 'N/A']
# ['Foreign_Exchange_Rate_Effect_on_Cash_and_Cash_Equivalents', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Discontinued_Operations_Cash_Flows, VALUE: N/A
# ['N/A', 'N/A']
# ['Discontinued_Operations_Cash_Flows', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Discontinued_Operations_Cash_Balance, VALUE: N/A
# ['N/A', 'N/A']
# ['Discontinued_Operations_Cash_Balance', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Change_In_Cash_Cash_Equiv, VALUE: N/A
# ['N/A', 'N/A']
# ['Change_In_Cash_Cash_Equiv', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Cash_And_Cash_Equivalents_Beginning_Of_Period, VALUE: N/A
# ['N/A', 'N/A']
# ['Cash_And_Cash_Equivalents_Beginning_Of_Period', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Cash_And_Cash_Equivalents_End_Of_Period, VALUE: N/A
# ['N/A', 'N/A']
# ['Cash_And_Cash_Equivalents_End_Of_Period', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Current_Assets, VALUE: $152,987M| $143,566M
# ['$152,987M', ' $143,566M', 'N/A']
# ['Current_Assets', '$152,987M', ' $143,566M']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Cash_and_Cash_Equivalents, VALUE: $29,943M| $29,965M
# ['$29,943M', ' $29,965M', 'N/A']
# ['Cash_and_Cash_Equivalents', '$29,943M', ' $29,965M']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Accounts_Receivables, VALUE: $33,410M| $29,508M
# ['$33,410M', ' $29,508M', 'N/A']
# ['Accounts_Receivables', '$33,410M', ' $29,508M']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Other_Current_Assets, VALUE: $14,287M| $14,695M
# ['$14,287M', ' $14,695M', 'N/A']
# ['Other_Current_Assets', '$14,287M', ' $14,695M']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Current_Assets_of_Discontinued_Operations, VALUE: N/A
# ['N/A', 'N/A']
# ['Current_Assets_of_Discontinued_Operations', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Total_Current_Assets, VALUE: $152,987M| $143,566M
# ['$152,987M', ' $143,566M', 'N/A']
# ['Total_Current_Assets', '$152,987M', ' $143,566M']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Property_Plant_and_Equipment_Net, VALUE: $45,680M| $43,715M
# ['$45,680M', ' $43,715M', 'N/A']
# ['Property_Plant_and_Equipment_Net', '$45,680M', ' $43,715M']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Goodwill, VALUE: N/A
# ['N/A', 'N/A']
# ['Goodwill', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Other_Intangiblesnet, VALUE: N/A
# ['N/A', 'N/A']
# ['Other_Intangiblesnet', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Other_Assets, VALUE: $74,834M| $64,758M
# ['$74,834M', ' $64,758M', 'N/A']
# ['Other_Assets', '$74,834M', ' $64,758M']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Noncurrent_Assets_of_Discontinued_Operations, VALUE: N/A
# ['N/A', 'N/A']
# ['Noncurrent_Assets_of_Discontinued_Operations', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Total_Assets, VALUE: $364,980M| $352,583M
# ['$364,980M', ' $352,583M', 'N/A']
# ['Total_Assets', '$364,980M', ' $352,583M']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Current_Liabilities, VALUE: $176,392M| $145,308M
# ['$176,392M', ' $145,308M', 'N/A']
# ['Current_Liabilities', '$176,392M', ' $145,308M']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Trade_Accounts_Payable, VALUE: $68,960M| $62,611M
# ['$68,960M', ' $62,611M', 'N/A']
# ['Trade_Accounts_Payable', '$68,960M', ' $62,611M']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Accrued_and_Other_Current_Liabilities, VALUE: N/A
# ['N/A', 'N/A']
# ['Accrued_and_Other_Current_Liabilities', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Due_to_Related_Party, VALUE: N/A
# ['N/A', 'N/A']
# ['Due_to_Related_Party', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Income_Taxes_Payable, VALUE: N/A
# ['N/A', 'N/A']
# ['Income_Taxes_Payable', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Current_Liabilities_of_Discontinued_Operations, VALUE: N/A
# ['N/A', 'N/A']
# ['Current_Liabilities_of_Discontinued_Operations', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Current_Portion_of_Debt, VALUE: N/A
# ['N/A', 'N/A']
# ['Current_Portion_of_Debt', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Total_Current_Liabilities, VALUE: $176,392M| $145,308M
# ['$176,392M', ' $145,308M', 'N/A']
# ['Total_Current_Liabilities', '$176,392M', ' $145,308M']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Long_Term_Debt, VALUE: $85,750M| $95,281M
# ['$85,750M', ' $95,281M', 'N/A']
# ['Long_Term_Debt', '$85,750M', ' $95,281M']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Deferred_Income_Taxes, VALUE: N/A
# ['N/A', 'N/A']
# ['Deferred_Income_Taxes', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Other_Noncurrent_Liabilities, VALUE: $45,888M| $49,848M
# ['$45,888M', ' $49,848M', 'N/A']
# ['Other_Noncurrent_Liabilities', '$45,888M', ' $49,848M']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Noncurrent_Liabilities_of_Discontinued_Operation, VALUE: N/A
# ['N/A', 'N/A']
# ['Noncurrent_Liabilities_of_Discontinued_Operation', 'N/A', 'N/A']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Total_Liabilities, VALUE: $308,030M| $290,437M
# ['$308,030M', ' $290,437M', 'N/A']
# ['Total_Liabilities', '$308,030M', ' $290,437M']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Shareholder_Equity, VALUE: $56,950M| $62,146M
# ['$56,950M', ' $62,146M', 'N/A']
# ['Shareholder_Equity', '$56,950M', ' $62,146M']
#
# type of key: <class 'str'>, type of value: <class 'str'>
# KEY: Total_Liabilities_And_Shareholders_Equities, VALUE: $364,980M| $352,583M
# ['$364,980M', ' $352,583M', 'N/A']
# ['Total_Liabilities_And_Shareholders_Equities', '$364,980M', ' $352,583M']

# %%
from openai import OpenAI
client = OpenAI()
client.models.list()
# Out:
# SyncPage[Model](data=[Model(id='dall-e-2', created=1698798177, object='model', owned_by='system'), Model(id='text-embedding-ada-002', created=1671217299, object='model', owned_by='openai-internal'), Model(id='gpt-4-1106-preview', created=1698957206, object='model', owned_by='system'), Model(id='gpt-4o', created=1715367049, object='model', owned_by='system'), Model(id='gpt-4o-2024-08-06', created=1722814719, object='model', owned_by='system'), Model(id='text-embedding-3-large', created=1705953180, object='model', owned_by='system'), Model(id='gpt-4o-mini-2024-07-18', created=1721172717, object='model', owned_by='system'), Model(id='babbage-002', created=1692634615, object='model', owned_by='system'), Model(id='gpt-4o-2024-11-20', created=1731975040, object='model', owned_by='system'), Model(id='gpt-4-turbo-preview', created=1706037777, object='model', owned_by='system'), Model(id='o1-mini', created=1725649008, object='model', owned_by='system'), Model(id='davinci-002', created=1692634301, object='model', owned_by='system'), Model(id='o1-mini-2024-09-12', created=1725648979, object='model', owned_by='system'), Model(id='gpt-4-0125-preview', created=1706037612, object='model', owned_by='system'), Model(id='whisper-1', created=1677532384, object='model', owned_by='openai-internal'), Model(id='dall-e-3', created=1698785189, object='model', owned_by='system'), Model(id='o1-preview', created=1725648897, object='model', owned_by='system'), Model(id='gpt-3.5-turbo-16k', created=1683758102, object='model', owned_by='openai-internal'), Model(id='o1-preview-2024-09-12', created=1725648865, object='model', owned_by='system'), Model(id='omni-moderation-latest', created=1731689265, object='model', owned_by='system'), Model(id='omni-moderation-2024-09-26', created=1732734466, object='model', owned_by='system'), Model(id='gpt-4o-realtime-preview', created=1727659998, object='model', owned_by='system'), Model(id='tts-1-hd-1106', created=1699053533, object='model', owned_by='system'), Model(id='gpt-4o-realtime-preview-2024-10-01', created=1727131766, object='model', owned_by='system'), Model(id='gpt-4', created=1687882411, object='model', owned_by='openai'), Model(id='gpt-4-0613', created=1686588896, object='model', owned_by='openai'), Model(id='gpt-4o-2024-05-13', created=1715368132, object='model', owned_by='system'), Model(id='gpt-3.5-turbo', created=1677610602, object='model', owned_by='openai'), Model(id='gpt-3.5-turbo-0125', created=1706048358, object='model', owned_by='system'), Model(id='text-embedding-3-small', created=1705948997, object='model', owned_by='system'), Model(id='gpt-4-turbo', created=1712361441, object='model', owned_by='system'), Model(id='tts-1-hd', created=1699046015, object='model', owned_by='system'), Model(id='gpt-4-turbo-2024-04-09', created=1712601677, object='model', owned_by='system'), Model(id='gpt-3.5-turbo-1106', created=1698959748, object='model', owned_by='system'), Model(id='gpt-3.5-turbo-instruct', created=1692901427, object='model', owned_by='system'), Model(id='gpt-4o-audio-preview', created=1727460443, object='model', owned_by='system'), Model(id='gpt-4o-audio-preview-2024-10-01', created=1727389042, object='model', owned_by='system'), Model(id='tts-1', created=1681940951, object='model', owned_by='openai-internal'), Model(id='tts-1-1106', created=1699053241, object='model', owned_by='system'), Model(id='gpt-3.5-turbo-instruct-0914', created=1694122472, object='model', owned_by='system'), Model(id='gpt-4o-mini', created=1721172741, object='model', owned_by='system'), Model(id='chatgpt-4o-latest', created=1723515131, object='model', owned_by='system')], object='list')
